# %%
import numpy

import pickle
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard

import time

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %%
X =  X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X, y, batch_size=30, epochs=5, validation_split=0.3)
# Out:
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 411 samples, validate on 177 samples
# Epoch 1/5
# 411/411 [==============================] - 9s 23ms/sample - loss: 0.6779 - acc: 0.5888 - val_loss: 0.6140 - val_acc: 0.6441
# Epoch 2/5
# 411/411 [==============================] - 7s 18ms/sample - loss: 0.6378 - acc: 0.6350 - val_loss: 0.6128 - val_acc: 0.6554
# Epoch 3/5
# 411/411 [==============================] - 7s 18ms/sample - loss: 0.6201 - acc: 0.6156 - val_loss: 0.5920 - val_acc: 0.6780
# Epoch 4/5
# 411/411 [==============================] - 7s 18ms/sample - loss: 0.6121 - acc: 0.6472 - val_loss: 0.6015 - val_acc: 0.6497
# Epoch 5/5
# 411/411 [==============================] - 8s 18ms/sample - loss: 0.5962 - acc: 0.6861 - val_loss: 0.5919 - val_acc: 0.6780

# %%
NAME = "Buy-Sell-CNN"

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'],
              )

model.fit(X, y,
          batch_size=32,
          epochs=7,
          validation_split=0.3,
          callbacks=[tensorboard])
# Out:
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 411 samples, validate on 177 samples
# Epoch 1/7
# 411/411 [==============================] - 9s 22ms/sample - loss: 0.6784 - acc: 0.5888 - val_loss: 0.6266 - val_acc: 0.6328
# Epoch 2/7
# 411/411 [==============================] - 8s 19ms/sample - loss: 0.6345 - acc: 0.6375 - val_loss: 0.6088 - val_acc: 0.6441
# Epoch 3/7
# 411/411 [==============================] - 8s 19ms/sample - loss: 0.6111 - acc: 0.6448 - val_loss: 0.6156 - val_acc: 0.6215
# Epoch 4/7
# 411/411 [==============================] - 8s 20ms/sample - loss: 0.5916 - acc: 0.6740 - val_loss: 0.5962 - val_acc: 0.6723
# Epoch 5/7
# 411/411 [==============================] - 9s 21ms/sample - loss: 0.5847 - acc: 0.6740 - val_loss: 0.6028 - val_acc: 0.6667
# Epoch 6/7
# 411/411 [==============================] - 8s 19ms/sample - loss: 0.5699 - acc: 0.6959 - val_loss: 0.6075 - val_acc: 0.6610
# Epoch 7/7
# 411/411 [==============================] - 8s 19ms/sample - loss: 0.5701 - acc: 0.6861 - val_loss: 0.6078 - val_acc: 0.6554

# %%
model.save('Test2-CNN.model')

# %% [markdown]
# ### For testing different elements

# %%
import time

dense_layers = [0,1,2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
# Out:
# 1-conv-32-nodes-0-dense-1590237584
# 2-conv-32-nodes-0-dense-1590237584
# 3-conv-32-nodes-0-dense-1590237584
# 1-conv-64-nodes-0-dense-1590237584
# 2-conv-64-nodes-0-dense-1590237584
# 3-conv-64-nodes-0-dense-1590237584
# 1-conv-128-nodes-0-dense-1590237584
# 2-conv-128-nodes-0-dense-1590237584
# 3-conv-128-nodes-0-dense-1590237584
# 1-conv-32-nodes-1-dense-1590237584
# 2-conv-32-nodes-1-dense-1590237584
# 3-conv-32-nodes-1-dense-1590237584
# 1-conv-64-nodes-1-dense-1590237584
# 2-conv-64-nodes-1-dense-1590237584
# 3-conv-64-nodes-1-dense-1590237584
# 1-conv-128-nodes-1-dense-1590237584
# 2-conv-128-nodes-1-dense-1590237584
# 3-conv-128-nodes-1-dense-1590237584
# 1-conv-32-nodes-2-dense-1590237584
# 2-conv-32-nodes-2-dense-1590237584
# 3-conv-32-nodes-2-dense-1590237584
# 1-conv-64-nodes-2-dense-1590237584
# 2-conv-64-nodes-2-dense-1590237584
# 3-conv-64-nodes-2-dense-1590237584
# 1-conv-128-nodes-2-dense-1590237584
# 2-conv-128-nodes-2-dense-1590237584
# 3-conv-128-nodes-2-dense-1590237584

# %%
dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, y,
                      batch_size=32,
                      epochs
10
# 411/411 [==============================] - 2s 4ms/sample - loss: 0.6233 - acc: 0.6594 - val_loss: 0.5997 - val_acc: 0.6610
# Epoch 6/10
# 411/411 [==============================] - 1s 4ms/sample - loss: 0.6077 - acc: 0.6740 - val_loss: 0.6090 - val_acc: 0.6667
# Epoch 7/10
# 411/411 [==============================] - 2s 4ms/sample - loss: 0.6017 - acc: 0.6764 - val_loss: 0.6169 - val_acc: 0.6271
# Epoch 8/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.6023 - acc: 0.6667 - val_loss: 0.6257 - val_acc: 0.6271
# Epoch 9/10
# 411/411 [==============================] - 3s 6ms/sample - loss: 0.6039 - acc: 0.6691 - val_loss: 0.6016 - val_acc: 0.6667
# Epoch 10/10
# 411/411 [==============================] - 2s 6ms/sample - loss: 0.5775 - acc: 0.7007 - val_loss: 0.6017 - val_acc: 0.6780
# 1-conv-128-nodes-0-dense-1590237671
# Train on 411 samples, validate on 177 samples
# Epoch 1/10
# 411/411 [==============================] - 4s 9ms/sample - loss: 0.6607 - acc: 0.5985 - val_loss: 0.6482 - val_acc: 0.6328
# Epoch 2/10
# 411/411 [==============================] - 2s 6ms/sample - loss: 0.6089 - acc: 0.6496 - val_loss: 0.5947 - val_acc: 0.6610
# Epoch 3/10
# 411/411 [==============================] - 3s 7ms/sample - loss: 0.5908 - acc: 0.6910 - val_loss: 0.6345 - val_acc: 0.6328
# Epoch 4/10
# 411/411 [==============================] - 3s 7ms/sample - loss: 0.5867 - acc: 0.6934 - val_loss: 0.6011 - val_acc: 0.6610
# Epoch 5/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.5709 - acc: 0.6910 - val_loss: 0.6238 - val_acc: 0.6384
# Epoch 6/10
# 411/411 [==============================] - 2s 6ms/sample - loss: 0.5655 - acc: 0.6934 - val_loss: 0.6157 - val_acc: 0.6384
# Epoch 7/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.5637 - acc: 0.7299 - val_loss: 0.6309 - val_acc: 0.6328
# Epoch 8/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.5576 - acc: 0.7178 - val_loss: 0.6115 - val_acc: 0.6723
# Epoch 9/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.5556 - acc: 0.7129 - val_loss: 0.6346 - val_acc: 0.6271
# Epoch 10/10
# 411/411 [==============================] - 2s 5ms/sample - loss: 0.5470 - acc: 0.7251 - val_loss: 0.6441 - val_acc: 0.6384
# 2-conv-128-nodes-0-dense-1590237697
# Train on 411 samples, validate on 177 samples
# Epoch 1/10
# 411/411 [==============================] - 6s 14ms/sample - loss: 0.6493 - acc: 0.6253 - val_loss: 0.6131 - val_acc: 0.6384
# Epoch 2/10
# 411/411 [==============================] - 3s 8ms/sample - loss: 0.6364 - acc: 0.6521 - val_loss: 0.5965 - val_acc: 0.6723
# Epoch 3/10
# 411/411 [==============================] - 4s 9ms/sample - loss: 0.6071 - acc: 0.6764 - val_loss: 0.6095 - val_acc: 0.6554
# Epoch 4/10
# 411/411 [==============================] - 3s 8ms/sample - loss: 0.5904 - acc: 0.6837 - val_loss: 0.6011 - val_acc: 0.6610
# Epoch 5/10
# 411/411 [==============================] - 3s 8ms/sample - loss: 0.5891 - acc: 0.6764 - val_loss: 0.6230 - val_acc: 0.6497
# Epoch 6/10
# 411/411 [==============================] - 3s 8ms/sample - loss: 0.5874 - acc: 0.6886 - val_loss: 0.6028 - val_acc: 0.6610
# Epoch 7/10
# 411/411 [==============================] - 3s 8ms/sample - loss: 0.5890 - acc: 0.6934 - val_loss: 0.5974 - val_acc: 0.6610
# Epoch 8/10
# 411/411 [==============================] - 4s 9ms/sample - loss: 0.5670 - acc: 0.6959 - val_loss: 0.6152 - val_acc: 0.6610
